# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_LA = pd.read_csv("/Users/monamuench/BananaCode/data/LosAngeles/la_2018.csv")
df_LA.drop_duplicates()
# Out:
#                  start_time             end_time  start_station_id  \
# 0       2018-01-01 00:04:00  2018-01-01 00:25:00              3063
# 1       2018-01-01 00:05:00  2018-01-01 00:25:00              3063
# 2       2018-01-01 00:06:00  2018-01-01 00:25:00              3063
# 3       2018-01-01 00:13:00  2018-01-01 00:35:00              3018
# 4       2018-01-01 00:14:00  2018-01-01 00:59:00              4204
# ...                     ...                  ...               ...
# 311889  2018-12-31 23:46:00  2018-12-31 23:55:00              3069
# 311890  2018-12-31 23:47:00  2018-12-31 23:54:00              3069
# 311891  2018-12-31 23:51:00  2019-01-01 01:28:00              4211
# 311892  2018-12-31 23:54:00  2019-01-01 00:22:00              3005
# 311893  2018-12-31 23:56:00  2019-01-01 00:22:00              3005
#
#         end_station_id  bike_id     user_type         start_station_name  \
# 0                 3018     5889       Walk-up            Pershing Square
# ...

# %%
df_LA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311894 entries, 0 to 311893
# Data columns (total 8 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   start_time          311894 non-null  object
#  1   end_time            311894 non-null  object
#  2   start_station_id    311894 non-null  int64
#  3   end_station_id      311894 non-null  int64
#  4   bike_id             311894 non-null  int64
#  5   user_type           311894 non-null  object
#  6   start_station_name  311894 non-null  object
#  7   end_station_name    311894 non-null  object
# dtypes: int64(3), object(5)
# memory usage: 19.0+ MB

# %%
df_LA.describe()
# Out:
#        start_station_id  end_station_id        bike_id
# count     311894.000000   311894.000000  311894.000000
# mean        3407.500500     3402.356624    8308.978724
# std          538.636065      537.619663    2918.540362
# min         3000.000000     3000.000000    4727.000000
# 25%         3030.000000     3030.000000    6084.000000
# 50%         3063.000000     3058.000000    6480.000000
# 75%         4163.000000     4162.000000   12097.000000
# max         4276.000000     4276.000000   15075.000000

# %%
df_LA['start_time'] = pd.to_datetime(df_LA['start_time'])
df_LA['end_time'] = pd.to_datetime(df_LA['end_time'])
df_LA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311894 entries, 0 to 311893
# Data columns (total 8 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   start_time          311894 non-null  datetime64[ns]
#  1   end_time            311894 non-null  datetime64[ns]
#  2   start_station_id    311894 non-null  int64
#  3   end_station_id      311894 non-null  int64
#  4   bike_id             311894 non-null  int64
#  5   user_type           311894 non-null  object
#  6   start_station_name  311894 non-null  object
#  7   end_station_name    311894 non-null  object
# dtypes: datetime64[ns](2), int64(3), object(3)
# memory usage: 19.0+ MB

# %%
def calculate_trip_time(df):
    # calculate the total trip duration in hours
    df['trip_duration'] = df.apply(lambda x: x['end_time'] - x['start_time'], axis=1) / pd.Timedelta(hours=1)
    #df['trip_duration'] = df['end_time'] - df['start_time']
    return df

# %%
df_trip = calculate_trip_time(df_LA)

# %%
df_LA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311894 entries, 0 to 311893
# Data columns (total 9 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   start_time          311894 non-null  datetime64[ns]
#  1   end_time            311894 non-null  datetime64[ns]
#  2   start_station_id    311894 non-null  int64
#  3   end_station_id      311894 non-null  int64
#  4   bike_id             311894 non-null  int64
#  5   user_type           311894 non-null  object
#  6   start_station_name  311894 non-null  object
#  7   end_station_name    311894 non-null  object
#  8   trip_duration       311894 non-null  timedelta64[ns]
# dtypes: datetime64[ns](2), int64(3), object(3), timedelta64[ns](1)
# memory usage: 21.4+ MB

# %%
# Fahrzeit plotten
# station name = id - distinct
# rumplotten

# %%
#%matplotlib inline 
#notebook

fig,ax = plt.subplots(figsize=(20,10), dpi= 80) 
axis_font = {'size':'20'}
label_font = {'labelsize':'12'}
dic={'fontsize': '24'}

ax.plot(df_LA['trip_duration'], color = 'tab:blue')
ax.set_title("Trip duration", dic)
ax.set_ylabel('hours',**axis_font)
ax.set_xlabel('Index of dataset',**axis_font)
ax.tick_params(axis='both', **label_font)
plt.show()

# %%
df_id = df_LA.sort_values(by=['bike_id','start_time'], ascending=True)
#df_id['check'] = False

#df.groupby(['start_station_id'])
#return df

df_unique_id = df_id.groupby('start_station_id')['start_station_name'].nunique().reset_index()
df_unique_name = df_id.groupby('start_station_name')['start_station_id'].nunique().reset_index()

print(df_unique_id)
print(df_unique_name)



print(df_unique_id.start_station_name.max())
print(df_unique_name.start_station_id.max())

#df_unique_name.sort_values(by=['start_station_id'], ascending = True)

#temp = pd.merge(df_unique_id, df_unique_name, on=[start_station_id], how='inner')
#temp.head()
    
#print(df_unique_id)
#print(df_unique_name)
#print(temp)
    
#for x in temp:
 #   if df_unique_id.start_station_id == df_unique_name.start_station_id:
  #      df.loc[index,'check'] = True
        
        
#unique_values_id =  pd.unique(df['start_station_id'])
#unique_values_name = pd.unique(df['start_station_name'])
    
#print (unique_values_id)
#print (unique_values_name)
# Out:
#      start_station_id  start_station_name
# 0                3000                   1
# 1                3005                   1
# 2                3006                   1
# 3                3007                   1
# 4                3008                   1
# ..                ...                 ...
# 127              4266                   1
# 128              4267                   1
# 129              4273                   1
# 130              4275                   1
# 131              4276                   1
#
# [132 rows x 2 columns]
#                start_station_name  start_station_id
# 0                    11th & Maple                 1
# 1                     12th & Hill                 1
# 2    17th St / SMC E Line Station                 1
# 3                 18th & Figueroa                 1
# 4                18th & San Pedro                 1
# ..                            ...               ...
# 127        Waterfront Park (East)                 1
# ...

# %%
df_LA.sort_values(by=['trip_duration'], ascending=True)
# Out:
#                 start_time            end_time  start_station_id  \
# 306334 2018-12-22 17:37:00 2018-12-22 17:38:00              3051
# 89971  2018-04-30 16:37:00 2018-04-30 16:38:00              3005
# 49864  2018-03-12 08:38:00 2018-03-12 08:39:00              4133
# 130783 2018-06-17 12:36:00 2018-06-17 12:37:00              4211
# 226064 2018-09-20 12:45:00 2018-09-20 12:46:00              3005
# ...                    ...                 ...               ...
# 306480 2018-12-23 02:51:00 2018-12-28 17:41:00              4204
# 244953 2018-10-07 16:14:00 2018-10-13 10:13:00              4210
# 61758  2018-03-27 18:12:00 2018-04-02 15:59:00              4162
# 129398 2018-06-15 14:17:00 2018-06-21 14:55:00              3068
# 306166 2018-12-22 14:20:00 2018-12-28 17:49:00              3033
#
#         end_station_id  bike_id     user_type  \
# 306334            3051    12064  Monthly Pass
# 89971             3064     6376  Monthly Pass
# ...

# %%
#sns.set_theme(); np.random.seed(0)

trip = df_trip['trip_duration'] < 6

sns.displot(trip)
# Out:
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
# KPIs:
# stündliche max. prozentuale Auslastung der Fahrräder
# 
#
