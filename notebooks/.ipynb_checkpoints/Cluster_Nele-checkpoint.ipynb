# %%
import numpy as np
import pandas as pd
from datetime import date, time, datetime, timedelta
from matplotlib import pyplot
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from math import sin, cos, pi

# %%
df=pd.read_csv('../data/LA.csv')
df["start_time"] = pd.to_datetime(df['start_time'])
df["end_time"] = pd.to_datetime(df['end_time'] ) 
df["trip_duration"] = pd.to_timedelta(df.trip_duration)
df.head()
# Out:
#            start_time            end_time  start_station_id  end_station_id  \
# 0 2018-01-01 00:04:00 2018-01-01 00:25:00              3063            3018
# 1 2018-01-01 00:05:00 2018-01-01 00:25:00              3063            3018
# 2 2018-01-01 00:06:00 2018-01-01 00:25:00              3063            3018
# 3 2018-01-01 00:13:00 2018-01-01 00:35:00              3018            3031
# 4 2018-01-01 00:14:00 2018-01-01 00:59:00              4204            4216
#
#    bike_id     user_type         start_station_name  \
# 0     5889       Walk-up            Pershing Square
# 1     6311       Walk-up            Pershing Square
# 2     5753       Walk-up            Pershing Square
# 3     6220  Monthly Pass            Grand & Olympic
# 4    12436  Monthly Pass  Washington & Abbot Kinney
#
#                end_station_name   trip_duration  trip_duration_in_hours
# 0               Grand & Olympic 0 days 00:21:00                0.350000
# 1               Grand & Olympic 0 days 00:20:00                0.333333
# 2               Grand & Olympic 0 days 00:19:00                0.316667
# 3                  7th & Spring 0 days 00:22:00                0.366667
# 4  17th St / SMC E Line Station 0 days 00:45:00                0.750000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306863 entries, 0 to 306862
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   start_time              306863 non-null  datetime64[ns]
#  1   end_time                306863 non-null  datetime64[ns]
#  2   start_station_id        306863 non-null  int64
#  3   end_station_id          306863 non-null  int64
#  4   bike_id                 306863 non-null  int64
#  5   user_type               306863 non-null  object
#  6   start_station_name      306863 non-null  object
#  7   end_station_name        306863 non-null  object
#  8   trip_duration           306863 non-null  timedelta64[ns]
#  9   trip_duration_in_hours  306863 non-null  float64
# dtypes: datetime64[ns](2), float64(1), int64(3), object(3), timedelta64[ns](1)
# memory usage: 23.4+ MB

# %%
df_sin_cos=df[["start_time","trip_duration_in_hours"]].copy()
df_sin_cos.loc[:,"hour"]= df_sin_cos.start_time.apply(lambda x: x.hour)
df_sin_cos.loc[:,"day_of_week"] = df_sin_cos.start_time.apply(lambda x: x.day_of_week)
df_sin_cos
# Out:
#                 start_time  trip_duration_in_hours  hour  day_of_week
# 0      2018-01-01 00:04:00                0.350000     0            0
# 1      2018-01-01 00:05:00                0.333333     0            0
# 2      2018-01-01 00:06:00                0.316667     0            0
# 3      2018-01-01 00:13:00                0.366667     0            0
# 4      2018-01-01 00:14:00                0.750000     0            0
# ...                    ...                     ...   ...          ...
# 306858 2018-12-31 23:31:00                0.383333    23            0
# 306859 2018-12-31 23:40:00                0.266667    23            0
# 306860 2018-12-31 23:42:00                0.233333    23            0
# 306861 2018-12-31 23:46:00                0.150000    23            0
# 306862 2018-12-31 23:47:00                0.116667    23            0
#
# [306863 rows x 4 columns]

# %%
def create_time_feature(name, feature, df, num_of_values):
    df[name+"_sin"]= feature.apply(lambda x: sin(2*pi*(x/num_of_values)))
    df[name+"_cos"]= feature.apply(lambda x: cos(2*pi*(x/num_of_values)))

# %%
create_time_feature("hour", df_sin_cos.hour, df_sin_cos, 24)
create_time_feature("day_of_week", df_sin_cos.day_of_week, df_sin_cos, 7)
df_sin_cos
# Out:
#                 start_time  trip_duration_in_hours  hour  day_of_week  \
# 0      2018-01-01 00:04:00                0.350000     0            0
# 1      2018-01-01 00:05:00                0.333333     0            0
# 2      2018-01-01 00:06:00                0.316667     0            0
# 3      2018-01-01 00:13:00                0.366667     0            0
# 4      2018-01-01 00:14:00                0.750000     0            0
# ...                    ...                     ...   ...          ...
# 306858 2018-12-31 23:31:00                0.383333    23            0
# 306859 2018-12-31 23:40:00                0.266667    23            0
# 306860 2018-12-31 23:42:00                0.233333    23            0
# 306861 2018-12-31 23:46:00                0.150000    23            0
# 306862 2018-12-31 23:47:00                0.116667    23            0
#
#         hour_sin  hour_cos  day_of_week_sin  day_of_week_cos
# 0       0.000000  1.000000              0.0              1.0
# 1       0.000000  1.000000              0.0              1.0
# 2       0.000000  1.000000              0.0              1.0
# 3       0.000000  1.000000              0.0              1.0
# 4       0.000000  1.000000              0.0              1.0
# ...          ...       ...              ...              ...
# 306858 -0.258819  0.965926              0.0              1.0
# 306859 -0.258819  0.965926              0.0              1.0
# 306860 -0.258819  0.965926              0.0              1.0
# 306861 -0.258819  0.965926              0.0              1.0
# 306862 -0.258819  0.965926              0.0              1.0
#
# [306863 rows x 8 columns]

# %%
X_df = df_sin_cos.drop(["hour","day_of_week","start_time"], axis=1)
X_df
# Out:
#         trip_duration_in_hours  hour_sin  hour_cos  day_of_week_sin  \
# 0                     0.350000  0.000000  1.000000              0.0
# 1                     0.333333  0.000000  1.000000              0.0
# 2                     0.316667  0.000000  1.000000              0.0
# 3                     0.366667  0.000000  1.000000              0.0
# 4                     0.750000  0.000000  1.000000              0.0
# ...                        ...       ...       ...              ...
# 306858                0.383333 -0.258819  0.965926              0.0
# 306859                0.266667 -0.258819  0.965926              0.0
# 306860                0.233333 -0.258819  0.965926              0.0
# 306861                0.150000 -0.258819  0.965926              0.0
# 306862                0.116667 -0.258819  0.965926              0.0
#
#         day_of_week_cos
# 0                   1.0
# 1                   1.0
# 2                   1.0
# 3                   1.0
# 4                   1.0
# ...                 ...
# 306858              1.0
# 306859              1.0
# 306860              1.0
# 306861              1.0
# 306862              1.0
#
# [306863 rows x 5 columns]

# %%
scaler = StandardScaler()
scaler.fit(X_df)
X_scaled_sin_cos = scaler.transform(X_df)
X_scaled_sin_cos_df = pd.DataFrame(X_scaled_sin_cos, columns=X_df.columns, index=X_df.index)
X_scaled_sin_cos_df
# Out:
#         trip_duration_in_hours  hour_sin  hour_cos  day_of_week_sin  \
# 0                    -0.139620  0.452370  2.394035         0.003411
# 1                    -0.165073  0.452370  2.394035         0.003411
# 2                    -0.190526  0.452370  2.394035         0.003411
# 3                    -0.114167  0.452370  2.394035         0.003411
# 4                     0.471256  0.452370  2.394035         0.003411
# ...                        ...       ...       ...              ...
# 306858               -0.088714  0.061911  2.334715         0.003411
# 306859               -0.266886  0.061911  2.334715         0.003411
# 306860               -0.317792  0.061911  2.334715         0.003411
# 306861               -0.445058  0.061911  2.334715         0.003411
# 306862               -0.495965  0.061911  2.334715         0.003411
#
#         day_of_week_cos
# 0                1.4169
# 1                1.4169
# 2                1.4169
# 3                1.4169
# 4                1.4169
# ...                 ...
# 306858           1.4169
# 306859           1.4169
# 306860           1.4169
# 306861           1.4169
# 306862           1.4169
#
# [306863 rows x 5 columns]

# %%
k_max = 20
clusters_sin_cos = []
losses_sin_cos = []

for k in range(k_max):
    model_sin_cos = KMeans(n_clusters=k+1,random_state=42,init="k-means++")
    model_sin_cos.fit(X_scaled_sin_cos)
    clusters_sin_cos.append(k+1)
    losses_sin_cos.append(model_sin_cos.inertia_)

# %%
plt.plot(clusters_sin_cos, losses_sin_cos)
plt.ylabel("Loss")
plt.xlabel("Number of clusters")
plt.show()

# %%
plt.plot(clusters_sin_cos, losses_sin_cos)
plt.ylabel("Loss")
plt.xlabel("Number of clusters")
plt.xlim([0,10])
plt.show()

# %%
# refit algorithm
six_means = KMeans(n_clusters=6, random_state=42,init="k-means++")
six_means.fit(X_scaled_sin_cos)

# refit algorithm
five_means = KMeans(n_clusters=5, random_state=42,init="k-means++")
five_means.fit(X_scaled_sin_cos)
# Out:
# KMeans(n_clusters=5, random_state=42)

# %%
numbers = ["zero", "one", "two", "three","four","five","six"]

X_scaled_sin_cos_df["cluster_six"] = six_means.predict(X_scaled_sin_cos)
X_scaled_sin_cos_df["cluster_six"] = X_scaled_sin_cos_df["cluster_six"].apply(lambda x: numbers[x])

X_scaled_sin_cos_df["cluster_five"] = five_means.predict(X_scaled_sin_cos)
X_scaled_sin_cos_df["cluster_five"] = X_scaled_sin_cos_df["cluster_five"].apply(lambda x: numbers[x])

X_scaled_sin_cos_df["duration"]= df_sin_cos.trip_duration_in_hours
X_scaled_sin_cos_df["hour"]=df_sin_cos.hour
X_scaled_sin_cos_df["day_of_week"]=df_sin_cos.day_of_week
X_scaled_sin_cos_df.reset_index(inplace=True)

# %%
sns.pairplot(data=X_scaled_sin_cos_df, hue="cluster_six",height=5, vars=["duration","day_of_week","hour"])

# %%
sns.pairplot(data=X_scaled_sin_cos_df, hue="cluster_five",height=5, vars=["duration","day_of_week","hour"])

# %%
fig,ax = plt.subplots(figsize=(20,10), dpi= 80) 
axis_font = {'size':'20'}
label_font = {'labelsize':'12'}
dic={'fontsize': '24'}
sns.kdeplot(data=X_scaled_sin_cos_df, x="hour", hue="cluster_six")
# Out:
# <AxesSubplot:xlabel='hour', ylabel='Density'>

# %%
fig,ax = plt.subplots(figsize=(20,10), dpi= 80) 
axis_font = {'size':'20'}
label_font = {'labelsize':'12'}
dic={'fontsize': '24'}
sns.kdeplot(data=X_scaled_sin_cos_df, x="day_of_week", hue="cluster_six")
# Out:
# <AxesSubplot:xlabel='day_of_week', ylabel='Density'>

# %%
fig,ax = plt.subplots(figsize=(20,20), dpi= 80) 
axis_font = {'size':'20'}
label_font = {'labelsize':'12'}
dic={'fontsize': '24'}
sns.kdeplot(data=X_scaled_sin_cos_df, x="duration", hue="cluster_six")
# Out:
# <AxesSubplot:xlabel='duration', ylabel='Density'>

# %%
fig,ax = plt.subplots(figsize=(20,10), dpi= 80) 
axis_font = {'size':'20'}
label_font = {'labelsize':'12'}
dic={'fontsize': '24'}
sns.kdeplot(data=X_scaled_sin_cos_df, x="hour", hue="cluster_five")
# Out:
# <AxesSubplot:xlabel='hour', ylabel='Density'>

# %%
fig,ax = plt.subplots(figsize=(20,10), dpi= 80) 
axis_font = {'size':'20'}
label_font = {'labelsize':'12'}
dic={'fontsize': '24'}
sns.kdeplot(data=X_scaled_sin_cos_df, x="day_of_week", hue="cluster_five")
# Out:
# <AxesSubplot:xlabel='day_of_week', ylabel='Density'>

# %%
fig,ax = plt.subplots(figsize=(20,20), dpi= 80) 
axis_font = {'size':'20'}
label_font = {'labelsize':'12'}
dic={'fontsize': '24'}
sns.kdeplot(data=X_scaled_sin_cos_df, x="duration", hue="cluster_five")
# Out:
# <AxesSubplot:xlabel='duration', ylabel='Density'>
